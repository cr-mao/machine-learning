# %% [markdown]
# ##  实现简单线性回归法

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.array([1., 2., 3., 4., 5.])
y = np.array([1., 3., 2., 3., 5.])

# %%
plt.scatter(x, y)
plt.axis([0, 6, 0, 6])
plt.show()

# %%
x_mean = np.mean(x)
y_mean = np.mean(y)

# %%
num = 0.0
d = 0.0
for x_i, y_i in zip(x, y):
    num += (x_i - x_mean) * (y_i - y_mean)
    d += (x_i - x_mean) ** 2

# %%
a = num/d

# %%
b = y_mean - a * x_mean

# %%
y_hat = a * x + b

# %%
plt.scatter(x, y)
plt.plot(x, y_hat, color='r')
plt.axis([0, 6, 0, 6])
plt.show()

# %%
x_predict = 6
y_predict = a * x_predict + b
y_predict
# Out:
# np.float64(5.2)

# %% [markdown]
# ### 封装我们自己的SimpleLinearRegression
#
# 代码参见 [这里](playML/SimpleLinearRegression.py)

# %%
from playML.SimpleLinearRegression import SimpleLinearRegression1

reg1 = SimpleLinearRegression1()
reg1.fit(x, y)
reg1.predict(np.array([x_predict]))
# Out:
# array([5.2])

# %%
reg1.a_
# Out:
# np.float64(0.8)

# %%
reg1.b_
# Out:
# np.float64(0.39999999999999947)

# %%
y_hat1 = reg1.predict(x)

# %%
plt.scatter(x, y)
plt.plot(x, y_hat1, color='r')
plt.axis([0, 6, 0, 6])
plt.show()

# %% [markdown]
# ### 向量化实现SimpleLinearRegression
#
# 代码参见 [这里](playML/SimpleLinearRegression.py)

# %%
from playML.SimpleLinearRegression import SimpleLinearRegression2

reg2 = SimpleLinearRegression2()
reg2.fit(x, y)
reg2.predict(np.array([x_predict]))
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 from playML.SimpleLinearRegression import SimpleLinearRegression2
#       3 reg2 = SimpleLinearRegression2()
#       4 reg2.fit(x, y)
#
# ImportError: cannot import name 'SimpleLinearRegression2' from 'playML.SimpleLinearRegression' (/Users/edgar/code/ai/machinelearning/linearRegression/01-SimpleLinearRegressionImplementation/playML/SimpleLinearRegression.py)

# %%
reg2.a_

# %%
reg2.b_

# %% [markdown]
# ### 向量化实现的性能测试

# %%
m = 1000000
big_x = np.random.random(size=m)
big_y = big_x * 2 + 3 + np.random.normal(size=m)
# %timeit reg1.fit(big_x, big_y)
# %timeit reg2.fit(big_x, big_y)

# %%
reg1.a_

# %%
reg1.b_

# %%
reg2.a_

# %%
reg2.b_
